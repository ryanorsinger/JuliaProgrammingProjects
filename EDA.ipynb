# %%
using RDatasets

# %%
for x in eachrow(RDatasets.datasets())
    println(x)
end
# Out:
# DataFrameRow
#  Row │ Package  Dataset  Title    Rows   Columns
#      │ String   String   String   Int64  Int64
# ─────┼───────────────────────────────────────────
#    1 │ COUNT    affairs  affairs    601       18
# DataFrameRow
#  Row │ Package  Dataset   Title     Rows   Columns
#      │ String   String    String    Int64  Int64
# ─────┼─────────────────────────────────────────────
#    2 │ COUNT    azdrg112  azdrg112   1798        4
# DataFrameRow
#  Row │ Package  Dataset  Title   Rows   Columns
#      │ String   String   String  Int64  Int64
# ─────┼──────────────────────────────────────────
#    3 │ COUNT    azpro    azpro    3589        6
# DataFrameRow
#  Row │ Package  Dataset    Title      Rows   Columns
#      │ String   String     String     Int64  Int64
# ─────┼───────────────────────────────────────────────
#    4 │ COUNT    badhealth  badhealth   1127        3
# DataFrameRow
#  Row │ Package  Dataset    Title      Rows   Columns
# ...

# %%
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa
#    6 │         5.4         3.9          1.7         0.4  setosa
#    7 │         4.6         3.4          1.4         0.3  setosa
#    8 │         5.0         3.4          1.5         0.2  setosa
#    9 │         4.4         2.9          1.4         0.2  setosa
#   10 │         4.9         3.1          1.5         0.1  setosa
#   11 │         5.4         3.7          1.5         0.2  setosa
# ...

# %%
# Names is a global function in Julia already
names(iris), size(iris)
# Out:
# (["SepalLength", "SepalWidth", "PetalLength", "PetalWidth", "Species"], (150, 5))

# %%
first(iris, 4)
# Out:
# 4×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa

# %%
last(iris, 3)
# Out:
# 3×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         6.5         3.0          5.2         2.0  virginica
#    2 │         6.2         3.4          5.4         2.3  virginica
#    3 │         5.9         3.0          5.1         1.8  virginica

# %%
first(iris)
# Out:
# DataFrameRow
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa

# %%
combine(groupby(iris, :Species, nrow))
# Out:
# MethodError: no method matching groupby(::DataFrame, ::Symbol, ::typeof(nrow))
# Closest candidates are:
#   groupby(::AbstractDataFrame, ::Any; sort, skipmissing) at /Users/xronos/.julia/packages/DataFrames/yqToF/src/groupeddataframe/groupeddataframe.jl:187
#
# Stacktrace:
#  [1] top-level scope at In[8]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# BREAKING CHANGES EVERYWHERE from v"1.x" to v"1.5.1"
# - head
# - tail
# - by
# - etc...
#
# ## TODOS
# - Figure out how to do `df.groupby("species").count`

# %%
describe(iris)
# Out:
# 5×7 DataFrame
#  Row │ variable     mean     min     median  max        nmissing  eltype       ⋯
#      │ Symbol       Union…   Any     Union…  Any        Int64     DataType     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SepalLength  5.84333  4.3     5.8     7.9               0  Float64      ⋯
#    2 │ SepalWidth   3.05733  2.0     3.0     4.4               0  Float64
#    3 │ PetalLength  3.758    1.0     4.35    6.9               0  Float64
#    4 │ PetalWidth   1.19933  0.1     1.3     2.5               0  Float64
#    5 │ Species               setosa          virginica         0  CategoricalV ⋯
#                                                                 1 column omitted

# %%
a, b, c = groupby(iris, [:Species])

println(first(a, 3))
# Out:
# 3×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa

# %%
# tool gorram long enough. 30 minutes, documentation, stack overflow, forums, etc... 
# just to see df.groupby("Species").Species.count()
combine(groupby(iris, [:Species]), nrow => :count)
# Out:
# 3×2 DataFrame
#  Row │ Species     count
#      │ Cat…        Int64
# ─────┼───────────────────
#    1 │ setosa         50
#    2 │ versicolor     50
#    3 │ virginica      50

# %%
# Julia 1.x book says describe(iris, stats=[:q25, :q75, :first, :last])
# but the api changed... go figure!
describe(iris, :q25, :q75, :first, :last)
# Out:
# 5×5 DataFrame
#  Row │ variable     q25     q75     first   last
#      │ Symbol       Union…  Union…  Any     Any
# ─────┼────────────────────────────────────────────────
#    1 │ SepalLength  5.1     6.4     5.1     5.9
#    2 │ SepalWidth   2.8     3.3     3.5     3.0
#    3 │ PetalLength  1.6     5.1     1.4     5.1
#    4 │ PetalWidth   0.3     1.8     0.2     1.8
#    5 │ Species                      setosa  virginica

# %%
describe(iris, :all)
# Out:
# 5×13 DataFrame
#  Row │ variable     mean     std       min     q25     median  q75     max     ⋯
#      │ Symbol       Union…   Union…    Any     Union…  Union…  Union…  Any     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SepalLength  5.84333  0.828066  4.3     5.1     5.8     6.4     7.9     ⋯
#    2 │ SepalWidth   3.05733  0.435866  2.0     2.8     3.0     3.3     4.4
#    3 │ PetalLength  3.758    1.7653    1.0     1.6     4.35    5.1     6.9
#    4 │ PetalWidth   1.19933  0.762238  0.1     0.3     1.3     1.8     2.5
#    5 │ Species                         setosa                          virgini ⋯
#                                                                6 columns omitted

# %%
using Statistics
# Out:
# WARNING: using Statistics.std in module Main conflicts with an existing identifier.

# %%
# Book's source of mean(iris[:SepalLength]) is not supported... go figure

# %%
mean(iris.SepalLength)
# Out:
# 5.843333333333334

# %%
median(iris.PetalLength)
# Out:
# 4.35

# %%
std(iris.PetalWidth)
# Out:
# 0.7596926279021595

# %%
using Statistics

# %%
# This nonsense from page 85 doesn't work 
# because of ArgumentError: syntax df[column] is not supported use df[!, column] instead
# for x in names(iris)[1:end - 1] # to exclude the species column
#     for y in names(iris)[1:end -1] # to exclude species
# #      /   println("$x \t $y $(cor(iris[x]))")
#     end
#     println("---")
# end

# %%
cor(iris.SepalWidth, iris.SepalLength)
# Out:
# -0.11756978413300206

# %%
cor([1, 2, 3], [1, 2, 4])
# Out:
# 0.9819805060619657

# %%
cov([1, 2, 3], [1, 2, 4])
# Out:
# 1.5

# %%
# Randomly sample from the df
rand(iris.SepalLength, 4)
# Out:
# 4-element Array{Float64,1}:
#  5.8
#  5.1
#  4.8
#  5.0

# %%
typeof(iris.SepalLength)
# Out:
# Array{Float64,1}

# %%
# VERY welcome surprise that gadfly's plot just worked w/o any jibberjabber!!
using Gadfly

# %%
plot(iris, x=:Species, y=:PetalLength, Geom.boxplot)
# Out:
# Plot(...)

# %%
plot(iris, x=:SepalLength, y=:PetalLength, color=:Species)
# Out:
# Plot(...)

# %%
plot(iris, x=:PetalLength, color=:Species, Geom.histogram)
# Out:
# Plot(...)

# %%
plot(iris, x=:PetalWidth, color=:Species, Geom.histogram)
# Out:
# Plot(...)

# %%
plot(iris, x=:PetalWidth, y=:PetalLength, color=:Species)
# Out:
# Plot(...)
